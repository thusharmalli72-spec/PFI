# %%
#Level 1: Variables & Data Types
name="thushar"
age=18
height=5.8
print(name,age,height)
# Out:
# thushar 18 5.8

# %%
number1=int(input("enter the number:"))
number2=int(input("enter the number:"))

print(type(number1))
print(type(number2))
# Out:
# enter the number: 16
# enter the number: 6
# <class 'int'>
# <class 'int'>

# %%
price=500
is_available=True
print(price,type(price))
print(is_available,type(is_available))
# Out:
# 500 <class 'int'>
# True <class 'bool'>

# %%
#Level 2: User Input & Output
name=input("enter your name:")
age=int(input("enter your age:"))

print("hello",name, "your age is",18)
# Out:
# enter your name: ram
# enter your age: 18
# hello ram your age is 18

# %%
num1=int(input("enter the value"))
num2=int(input("enter the value"))

print("sum",num1+num2)
print("difference",num1-num2)
print("product",num1*num2)
print("quotient",num1/num2)
# Out:
# enter the value 98
# enter the value 6
# sum 104
# difference 92
# product 588
# quotient 16.333333333333332

# %%
price=int(input("enter the price:"))
quantity=int(input("enter the quantity:"))
print("total cost",price* quantity)
# Out:
# enter the price: 89
# enter the quantity: 95
# total cost 8455

# %%
#Level 3: Arithmetic Operators
num1=int(input("enter the value"))
num2=int(input("enter the value"))

print("addition=", num1+num2)
print("sumtraction=",num1-num2)
print("multiplication=",num1*num2)
print("divison=",num1/num2)
print("floor divison=",num1//num2)
print("moduless",num1%num2)
print("power",num1**num2)
# Out:
# enter the value 1
# enter the value 2
# addition= 3
# sumtraction= -1
# multiplication= 2
# divison= 0.5
# floor divison= 0
# moduless 1
# power 1

# %%
iteam_price=1000
sales=1200
print("profit",sales-iteam_price)
# Out:
# profit 200

# %%
iteam_price=1500
sales=1300
print("lose",sales-iteam_price)
# Out:
# lose -200

# %%
#Level 4: Business/Financial Calculations
product_price=2000
discount_rate=20
discount_rate=product_price*discount_rate/100
final_price=product_price-discount_rate

print("discount=",discount)
print("final_price=", final_price)
# Out:
# discount= 400.0
# final_price= 1600.0

# %%
cost_price=int(input("enter the cost price:"))
selling_price=int(input("enter the selling price:"))

if selling_price > cost_price:
    profit= selling_price-cost_price
    profit_percent=(profit/cost_price*100)
    print("profit=",profit)
    print("profit_percent=",profit_percent)
elif selling_price < cost_price:
    loss=selling_price-cost_price
    loss_percent=(loss/cost_price*100)
    print("loss=",loss)
    print("loss_percent=",loss_percent)
else:
    print("NO PROFIT OR NO LOSS")
# Out:
# enter the cost price: 10000
# enter the selling price: 15000
# profit= 5000
# profit_percent= 50.0

# %%
price=int(input("enter the price of the product:"))
GST=int(input("enter the GST:"))

GST_amount=price*GST/100
final_price=price+GST
print("GST_amount",GST)
print("final_amount",final_price)
# Out:
# enter the price of the product: 1000
# enter the GST: 18
# GST_amount 18
# final_amount 1018

# %%
income=int(input("enter your income:"))
if income <= 500000:
    Tax=0
else:
    Tax=(income-500000*10/100)
print("Tax amount=",Tax)
# Out:
# enter your income: 600000
# Tax amount= 550000.0

# %%
cost_price = float(input("Enter cost price: "))
selling_price = float(input("Enter selling price: "))
gst_rate = float(input("Enter GST rate: "))
discount_rate = float(input("Enter discount rate: "))


if selling_price > cost_price:
    profit = selling_price - cost_price
    print("Profit =", profit)

elif selling_price < cost_price:
    loss = cost_price - selling_price
    print("Loss =", loss)

else:
    print("No profit, no loss")


discount = selling_price * discount_rate / 100
price_after_discount = selling_price - discount

print("Price after discount =", price_after_discount)


gst_amount = price_after_discount * gst_rate / 100
final_price = price_after_discount + gst_amount

print("GST amount =", gst_amount)
print("Final price =", final_price)
# Out:
# Enter cost price:  10000
# Enter selling price:  2000
# Enter GST rate:  18
# Enter discount rate:  20
# Loss = 8000.0
# Price after discount = 1600.0
# GST amount = 288.0
# Final price = 1888.0
