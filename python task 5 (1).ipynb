# %%
import pandas as pd

# %%
df=pd.read_excel("fin_data.xlsx")

# %%
df
# Out:
#     Transaction_ID        Date Customer   Product     Category  Quantity  \
# 0             1001  2026-01-01      Anu    Laptop  Electronics         2
# 1             1002  2026-01-02    Rahul    Mobile  Electronics         1
# 2             1003  2026-01-03    Meena    Tablet  Electronics         3
# 3             1004  2026-01-04    Arjun   Monitor  Electronics         2
# 4             1005  2026-01-05    Priya  Keyboard  Accessories         5
# 5             1006  2026-01-06   Vishnu     Mouse  Accessories         4
# 6             1007  2026-01-07     Neha   Printer       Office         1
# 7             1008  2026-01-08    Akhil    Laptop  Electronics         1
# 8             1009  2026-01-09    Sneha    Mobile  Electronics         2
# 9             1010  2026-01-10    Rohan    Tablet  Electronics         3
# 10            1011  2026-01-11     Diya   Monitor  Electronics         2
# 11            1012  2026-01-12    Kiran  Keyboard  Accessories         6
# ...

# %%
df.shape
# Out:
# (25, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction_ID  25 non-null     int64
#  1   Date            25 non-null     object
#  2   Customer        25 non-null     object
#  3   Product         25 non-null     object
#  4   Category        25 non-null     object
#  5   Quantity        25 non-null     int64
#  6   Sales_Amount    25 non-null     int64
#  7   Profit          25 non-null     int64
#  8   Payment_Mode    25 non-null     object
# dtypes: int64(4), object(5)
# memory usage: 1.9+ KB

# %%
df.tail(2)
# Out:
#     Transaction_ID        Date Customer  Product     Category  Quantity  \
# 23            1024  2026-01-24     Hari   Tablet  Electronics         3
# 24            1025  2026-01-25     Amal  Monitor  Electronics         2
#
#     Sales_Amount  Profit Payment_Mode
# 23         46000    7000          UPI
# 24         29000    4300         Card

# %%
df.head()
# Out:
#    Transaction_ID        Date Customer   Product     Category  Quantity  \
# 0            1001  2026-01-01      Anu    Laptop  Electronics         2
# 1            1002  2026-01-02    Rahul    Mobile  Electronics         1
# 2            1003  2026-01-03    Meena    Tablet  Electronics         3
# 3            1004  2026-01-04    Arjun   Monitor  Electronics         2
# 4            1005  2026-01-05    Priya  Keyboard  Accessories         5
#
#    Sales_Amount  Profit Payment_Mode
# 0         90000   12000          UPI
# 1         35000    5000         Card
# 2         45000    7000         Cash
# 3         30000    4500          UPI
# 4          7500    1500         Card

# %%
df.describe()
# Out:
#        Transaction_ID  Quantity  Sales_Amount        Profit
# count       25.000000  25.00000     25.000000     25.000000
# mean      1013.000000   2.60000  32640.000000   4952.000000
# std          7.359801   1.47196  21737.314308   2973.090424
# min       1001.000000   1.00000   4000.000000    800.000000
# 25%       1007.000000   2.00000  18000.000000   3000.000000
# 50%       1013.000000   2.00000  32000.000000   4800.000000
# 75%       1019.000000   3.00000  45000.000000   7000.000000
# max       1025.000000   6.00000  90000.000000  12000.000000

# %%
import pandas as pd 
df=pd.read_json("financial_practice_25_records.json")

# %%
df
# Out:
#     Transaction_ID       Date Customer   Product     Category  Quantity  \
# 0             1001 2026-01-01      Anu    Laptop  Electronics         2
# 1             1002 2026-01-02    Rahul    Mobile  Electronics         1
# 2             1003 2026-01-03    Meena    Tablet  Electronics         3
# 3             1004 2026-01-04    Arjun   Monitor  Electronics         2
# 4             1005 2026-01-05    Priya  Keyboard  Accessories         5
# 5             1006 2026-01-06   Vishnu     Mouse  Accessories         4
# 6             1007 2026-01-07     Neha   Printer       Office         1
# 7             1008 2026-01-08    Akhil    Laptop  Electronics         1
# 8             1009 2026-01-09    Sneha    Mobile  Electronics         2
# 9             1010 2026-01-10    Rohan    Tablet  Electronics         3
# 10            1011 2026-01-11     Diya   Monitor  Electronics         2
# 11            1012 2026-01-12    Kiran  Keyboard  Accessories         6
# ...

# %%
df.shape
# Out:
# (25, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction_ID  25 non-null     int64
#  1   Date            25 non-null     datetime64[ns]
#  2   Customer        25 non-null     object
#  3   Product         25 non-null     object
#  4   Category        25 non-null     object
#  5   Quantity        25 non-null     int64
#  6   Sales_Amount    25 non-null     int64
#  7   Profit          25 non-null     int64
#  8   Payment_Mode    25 non-null     object
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 1.9+ KB

# %%
df.describe()
# Out:
#        Transaction_ID                 Date  Quantity  Sales_Amount  \
# count       25.000000                   25  25.00000     25.000000
# mean      1013.000000  2026-01-13 00:00:00   2.60000  32640.000000
# min       1001.000000  2026-01-01 00:00:00   1.00000   4000.000000
# 25%       1007.000000  2026-01-07 00:00:00   2.00000  18000.000000
# 50%       1013.000000  2026-01-13 00:00:00   2.00000  32000.000000
# 75%       1019.000000  2026-01-19 00:00:00   3.00000  45000.000000
# max       1025.000000  2026-01-25 00:00:00   6.00000  90000.000000
# std          7.359801                  NaN   1.47196  21737.314308
#
#              Profit
# count     25.000000
# mean    4952.000000
# min      800.000000
# 25%     3000.000000
# 50%     4800.000000
# 75%     7000.000000
# max    12000.000000
# std     2973.090424

# %%
df.head(10)
# Out:
#    Transaction_ID       Date Customer   Product     Category  Quantity  \
# 0            1001 2026-01-01      Anu    Laptop  Electronics         2
# 1            1002 2026-01-02    Rahul    Mobile  Electronics         1
# 2            1003 2026-01-03    Meena    Tablet  Electronics         3
# 3            1004 2026-01-04    Arjun   Monitor  Electronics         2
# 4            1005 2026-01-05    Priya  Keyboard  Accessories         5
# 5            1006 2026-01-06   Vishnu     Mouse  Accessories         4
# 6            1007 2026-01-07     Neha   Printer       Office         1
# 7            1008 2026-01-08    Akhil    Laptop  Electronics         1
# 8            1009 2026-01-09    Sneha    Mobile  Electronics         2
# 9            1010 2026-01-10    Rohan    Tablet  Electronics         3
#
#    Sales_Amount  Profit Payment_Mode
# 0         90000   12000          UPI
# 1         35000    5000         Card
# 2         45000    7000         Cash
# ...

# %%
df.tail(2)
# Out:
#     Transaction_ID       Date Customer  Product     Category  Quantity  \
# 23            1024 2026-01-24     Hari   Tablet  Electronics         3
# 24            1025 2026-01-25     Amal  Monitor  Electronics         2
#
#     Sales_Amount  Profit Payment_Mode
# 23         46000    7000          UPI
# 24         29000    4300         Card

# %%
df=pd.read_csv("Marks.csv")

# %%
df
# Out:
#    Student_Name   Math  Science  English  Computer  Attendance
# 0     Student_1   48.0     43.0      NaN      57.0        91.0
# 1     Student_2   88.0      NaN     75.0      91.0        84.0
# 2     Student_3    NaN     61.0     51.0      81.0        61.0
# 3     Student_4   97.0     84.0     72.0       NaN        60.0
# 4     Student_5   84.0     92.0     62.0      96.0         NaN
# 5     Student_6    NaN     48.0     65.0      51.0        61.0
# 6     Student_7   41.0      NaN     69.0      93.0        73.0
# 7     Student_8   67.0     38.0     78.0      64.0        88.0
# 8     Student_9  100.0     98.0      NaN      64.0        82.0
# 9    Student_10    NaN     63.0     93.0      79.0        78.0
# 10   Student_11   99.0      NaN     71.0      85.0        66.0
# 11   Student_12   51.0     72.0     52.0       NaN        81.0
# 12   Student_13    NaN     99.0     72.0      82.0        72.0
# 13   Student_14   59.0     71.0     82.0      81.0         NaN
# ...

# %%
df.shape
# Out:
# (50, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student_Name  50 non-null     object
#  1   Math          40 non-null     float64
#  2   Science       39 non-null     float64
#  3   English       44 non-null     float64
#  4   Computer      44 non-null     float64
#  5   Attendance    44 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
#              Math     Science     English    Computer  Attendance
# count   40.000000   39.000000   44.000000   44.000000   44.000000
# mean    73.000000   66.641026   70.772727   75.500000   78.000000
# std     17.727279   19.137298   14.636469   15.515184   11.214608
# min     41.000000   35.000000   45.000000   50.000000   60.000000
# 25%     59.000000   53.000000   60.500000   62.500000   69.250000
# 50%     73.000000   67.000000   71.500000   78.000000   79.000000
# 75%     89.250000   78.500000   79.000000   88.250000   87.000000
# max    100.000000  100.000000  100.000000  100.000000   95.000000

# %%
df.head(5)
# Out:
#   Student_Name  Math  Science  English  Computer  Attendance
# 0    Student_1  48.0     43.0      NaN      57.0        91.0
# 1    Student_2  88.0      NaN     75.0      91.0        84.0
# 2    Student_3   NaN     61.0     51.0      81.0        61.0
# 3    Student_4  97.0     84.0     72.0       NaN        60.0
# 4    Student_5  84.0     92.0     62.0      96.0         NaN

# %%
df.tail(3)
# Out:
#    Student_Name  Math  Science  English  Computer  Attendance
# 47   Student_48  59.0     44.0     99.0      54.0        79.0
# 48   Student_11  99.0      NaN     71.0      85.0        66.0
# 49   Student_21  72.0      NaN     45.0      99.0        72.0

# %%
import pandas as pd
S=pd.Series([10,20,30,40])
print(S)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
S.shape
# Out:
# (4,)

# %%
S.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4 entries, 0 to 3
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 4 non-null      int64
# dtypes: int64(1)
# memory usage: 164.0 bytes

# %%
S.describe()
# Out:
# count     4.000000
# mean     25.000000
# std      12.909944
# min      10.000000
# 25%      17.500000
# 50%      25.000000
# 75%      32.500000
# max      40.000000
# dtype: float64

# %%
S.head()
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
S.tail()
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data = {"Name": ["Thushar", "wilson", "yajnesh"], "Marks": [80, 90, 85]} 
df = pd.DataFrame(data) 
print(df)
# Out:
#       Name  Marks
# 0  Thushar     80
# 1   wilson     90
# 2  yajnesh     85

# %%
df.shape
# Out:
# (3, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Marks   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
df.head()
# Out:
#       Name  Marks
# 0  Thushar     80
# 1   wilson     90
# 2  yajnesh     85

# %%
df.tail()
# Out:
#       Name  Marks
# 0  Thushar     80
# 1   wilson     90
# 2  yajnesh     85

# %%
df.describe()
# Out:
#        Marks
# count    3.0
# mean    85.0
# std      5.0
# min     80.0
# 25%     82.5
# 50%     85.0
# 75%     87.5
# max     90.0
