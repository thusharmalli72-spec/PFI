# %%
def simple_interest(p,r,t):
    si=(p*r*t)/100
    return si

# %%
def compound_interest(p,r,t):
    ci=p=(1+r/100)**t
    ci=amount-p
    return ci

# %%
n=int(input("enter the number of customers"))
for i in range(n):
    print("\n customers",i+1)
    p=int(input("enter the principle:"))
    r=int(input("enter the rate:"))
    t=int(input("enter the time:"))
    si=simple_interest(p,r,t)
    ci=compound_interest(p,r,t)
    print("simple_interest",si)
    print("compound_interest",ci)
# Out:
# enter the number of customers 1
#  customers 1
# enter the principle: 5555
# enter the rate: 4
# enter the time: 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 8
#       6 t=int(input("enter the time:"))
#       7 si=simple_interest(p,r,t)
# ----> 8 ci=compound_interest(p,r,t)
#       9 print("simple_interest",si)
#      10 print("compound_interest",ci)
#
# Cell In[14], line 3, in compound_interest(p, r, t)
#       1 def compound_interest(p,r,t):
#       2     ci=p=(1+r/100)**t
# ----> 3     ci=amount-p
#       4     return ci
#
# NameError: name 'amount' is not defined
