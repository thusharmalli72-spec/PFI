# %%
balance=int(input("enter the balance"))
T=int(input("enter the transactions"))
transactions=[]
for i in range(T):
    print("\n Transactions",i+1)
    amount=int(input("enter the amount:"))
    transaction_type=input("Debit or Credit:")
    transactions.append([amount,transaction_type])

for transaction in transactions:
    amount=transaction[0]
    transaction_type=transaction[1]

    if transaction_type.lower()=="credit":
        balance=balance+amount
    elif transaction_type.upper()=="debit":
        balance=balance-amount
    else:
        print("invailed input")
        
print(" Final balance",balance)
# Out:
# enter the balance 111111
# enter the transactions a
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 balance=int(input("enter the balance"))
# ----> 2 T=int(input("enter the transactions"))
#       3 transactions=[]
#       4 for i in range(T):
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
try:
    balance=int(input("enter the balance"))
    T=int(input("enter the transactions"))
    transactions=[]
    for i in range(T):
        print("\n Transactions",i+1)
        try:
            amount=int(input("enter the amount:"))
            transaction_type=input("Debit or Credit:")
            transactions.append([amount,transaction_type])
        except ValueError:
            print("invalid input,enter the valied input")

    for transaction in transactions:
        amount=transaction[0]
        transaction_type=transaction[1]

    if transaction_type.lower()=="credit":
        balance=balance+amount
    elif transaction_type.upper()=="debit":
        balance=balance-amount
    else:
        print("invailed input")
        
    print("Final balance",balance)
except ValueError:
    print("invalid input,enter the valied input")
# Out:
# enter the balance 100000
# enter the transactions 3
#  Transactions 1
# enter the amount: credit
# invalid input,enter the valied input
#
#  Transactions 2
# enter the amount: 50000
# Debit or Credit: debit
#  Transactions 3
# enter the amount: debit
# invalid input,enter the valied input
# invailed input
# Final balance 100000
