# %%
#1
customers={
           "name" : "amit",
           "balance" : 5000
}

# %%
if customers ["balance"] > 3000:
    print (" good balance")
else:
    print("low balance")
# Out:
#  good balance

# %%
#2
account = ("priya","saving")

# %%
if  account[1]=="savings":
    print("savings")

# %%
account[1]
# Out:
# 'saving'

# %%
#3
customers = ["amit","priya","rahul"]

# %%
for name in customers:
    print (name)
# Out:
# amit
# priya
# rahul

# %%
#4
transaction = [500,-200,1000,-700]
for amount in transaction:
    if amount > 0:
        print("Credit")
    elif amount < 0:
       print("Debit")
# Out:
# Credit
# Debit
# Credit
# Debit

# %%
#5
transactions=[2000,4000,6000,7000,9000]
for amount in transactions:
    if amount >5000:
        print("Large")
    else: 
        print ("Small")
# Out:
# Small
# Small
# Large
# Large
# Large

# %%
#6
balance=10000
debit=int(input("enter the amount"))
if debit <= balance:
    print ("debit successful")
else:
    print ("Insufficient balance")
# Out:
# enter the amount 5
# debit successful

# %%
#7
account={"balance":8000}
amount=int(input("enter amount to draw"))
if amount <=account["balance"]:
    account["balance"]=account["balance"]-amount
    print("new balance=",account["balance"])
else:
    print("Insufficient balance")
# Out:
# enter amount to draw 1000
# new balance= 7000

# %%
#8
transaction=[("Credit", 1000), ("Debit", 500)]
for amount in transactions:
    if transaction[0] =="Credit":
        print("added")
    elif transaction[0] =="Debit":
        print("deducted")
